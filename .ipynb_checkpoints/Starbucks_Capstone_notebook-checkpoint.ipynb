# %% [markdown]
# # Starbucks Capstone Challenge
#
# ### Introduction
#
# This data set contains simulated data that mimics customer behavior on the Starbucks rewards mobile app. Once every few days, Starbucks sends out an offer to users of the mobile app. An offer can be merely an advertisement for a drink or an actual offer such as a discount or BOGO (buy one get one free). Some users might not receive any offer during certain weeks.
#
# Not all users receive the same offer, and that is the challenge to solve with this data set.
#
# Your task is to combine transaction, demographic and offer data to determine which demographic groups respond best to which offer type. This data set is a simplified version of the real Starbucks app because the underlying simulator only has one product whereas Starbucks actually sells dozens of products.
#
# Every offer has a validity period before the offer expires. As an example, a BOGO offer might be valid for only 5 days. You'll see in the data set that informational offers have a validity period even though these ads are merely providing information about a product; for example, if an informational offer has 7 days of validity, you can assume the customer is feeling the influence of the offer for 7 days after receiving the advertisement.
#
# You'll be given transactional data showing user purchases made on the app including the timestamp of purchase and the amount of money spent on a purchase. This transactional data also has a record for each offer that a user receives as well as a record for when a user actually views the offer. There are also records for when a user completes an offer.
#
# Keep in mind as well that someone using the app might make a purchase through the app without having received an offer or seen an offer.
#
# ### Example
#
# To give an example, a user could receive a discount offer buy 10 dollars get 2 off on Monday. The offer is valid for 10 days from receipt. If the customer accumulates at least 10 dollars in purchases during the validity period, the customer completes the offer.
#
# However, there are a few things to watch out for in this data set. Customers do not opt into the offers that they receive; in other words, a user can receive an offer, never actually view the offer, and still complete the offer. For example, a user might receive the "buy 10 dollars get 2 dollars off offer", but the user never opens the offer during the 10 day validity period. The customer spends 15 dollars during those ten days. There will be an offer completion record in the data set; however, the customer was not influenced by the offer because the customer never viewed the offer.
#
# ### Cleaning
#
# This makes data cleaning especially important and tricky.
#
# You'll also want to take into account that some demographic groups will make purchases even if they don't receive an offer. From a business perspective, if a customer is going to make a 10 dollar purchase without an offer anyway, you wouldn't want to send a buy 10 dollars get 2 dollars off offer. You'll want to try to assess what a certain demographic group will buy when not receiving any offers.
#
# ### Final Advice
#
# Because this is a capstone project, you are free to analyze the data any way you see fit. For example, you could build a machine learning model that predicts how much someone will spend based on demographics and offer type. Or you could build a model that predicts whether or not someone will respond to an offer. Or, you don't need to build a machine learning model at all. You could develop a set of heuristics that determine what offer you should send to each customer (i.e., 75 percent of women customers who were 35 years old responded to offer A vs 40 percent from the same demographic to offer B, so send offer A).

# %% [markdown]
# # Data Sets
#
# The data is contained in three files:
#
# * portfolio.json - containing offer ids and meta data about each offer (duration, type, etc.)
# * profile.json - demographic data for each customer
# * transcript.json - records for transactions, offers received, offers viewed, and offers completed
#
# Here is the schema and explanation of each variable in the files:
#
# **portfolio.json**
# * id (string) - offer id
# * offer_type (string) - type of offer ie BOGO, discount, informational
# * difficulty (int) - minimum required spend to complete an offer
# * reward (int) - reward given for completing an offer
# * duration (int) - time for offer to be open, in days
# * channels (list of strings)
#
# **profile.json**
# * age (int) - age of the customer
# * became_member_on (int) - date when customer created an app account
# * gender (str) - gender of the customer (note some entries contain 'O' for other rather than M or F)
# * id (str) - customer id
# * income (float) - customer's income
#
# **transcript.json**
# * event (str) - record description (ie transaction, offer received, offer viewed, etc.)
# * person (str) - customer id
# * time (int) - time in hours since start of test. The data begins at time t=0
# * value - (dict of strings) - either an offer id or transaction amount depending on the record
#
# **Note:** If you are using the workspace, you will need to go to the terminal and run the command `conda update pandas` before reading in the files. This is because the version of pandas in the workspace cannot read in the transcript.json file correctly, but the newest version of pandas can. You can access the termnal from the orange icon in the top left of this notebook.
#
# You can see how to access the terminal and how the install works using the two images below.  First you need to access the terminal:
#
# <img src="pic1.png"/>
#
# Then you will want to run the above command:
#
# <img src="pic2.png"/>
#
# Finally, when you enter back into the notebook (use the jupyter icon again), you should be able to run the below cell without any errors.

# %%
import pandas as pd
import numpy as np
import math
import json
# %matplotlib inline
import matplotlib.pyplot as plt

# read in the json files
portfolio = pd.read_json('data/portfolio.json', orient='records', lines=True)
profile = pd.read_json('data/profile.json', orient='records', lines=True)
transcript = pd.read_json('data/transcript.json', orient='records', lines=True)

# %%
transcript.head()
# Out:
#                              person           event  \
# 0  78afa995795e4d85b5d9ceeca43f5fef  offer received
# 1  a03223e636434f42ac4c3df47e8bac43  offer received
# 2  e2127556f4f64592b11af22de27a7932  offer received
# 3  8ec6ce2a7e7949b1bf142def7d0e0586  offer received
# 4  68617ca6246f4fbc85e91a2a49552598  offer received
#
#                                               value  time
# 0  {'offer id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'}     0
# 1  {'offer id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'}     0
# 2  {'offer id': '2906b810c7d4411798c6938adc9daaa5'}     0
# 3  {'offer id': 'fafdcd668e3743c1bb461111dcafc2a4'}     0
# 4  {'offer id': '4d5c57ea9a6940dd891ad53e9dbe8da0'}     0

# %%
transcript['event'].unique()
# Out:
# array(['offer received', 'offer viewed', 'transaction', 'offer completed'],
#       dtype=object)

# %%
original_size = transcript.size
transcript.dropna(inplace=True)
print("transcript - original size {} , size after dropping na {}".format(original_size, transcript.size))
# Out:
# transcript - original size 1226136 , size after dropping na 1226136

# %%
#lets see what are the keys in transcript.value

for event_name in transcript['event'].unique():
    subset = transcript[transcript['event']==event_name]
    #print(subset.iloc[0,2])
    if (type (subset.iloc[0,2]) is dict ):
       print("{}  :  {}".format(event_name,subset.iloc[0,2].keys()))
# Out:
# offer received  :  dict_keys(['offer id'])
# offer viewed  :  dict_keys(['offer id'])
# transaction  :  dict_keys(['amount'])
# offer completed  :  dict_keys(['offer_id', 'reward'])

# %%
original_size = profile.size
profile.dropna(inplace=True)
print("profile - original size {} , size after dropping na {}".format(original_size, profile.size))
# Out:
# profile - original size 85000 , size after dropping na 74125

# %%
original_size = portfolio.size
portfolio.dropna(inplace=True)
print("portfolio - original size {} , size after dropping na {}".format(original_size, portfolio.size))
# Out:
# portfolio - original size 60 , size after dropping na 60

# %%
profile['gender'].value_counts()
# Out:
# M    8484
# F    6129
# O     212
# Name: gender, dtype: int64

# %%
profile['gender'].hist()

# %% [markdown]
# ## Lets analyze the transcript dataset

# %% [markdown]
# We have three different keys in the **value** column offer id, offer_id ,  amount and reward

# %%
def determine_offerid_value(d):
    return d['offer_id'] if (d.get('offer_id') is not None) else d.get('offer id')

# %% [markdown]
# ### Let's add a new column to the transcript dataframe for each key that is in the Value column, we already know that they are (amount, reward, offer_id and offer id )

# %%
transcript.loc[:,'offer_id'] = transcript['value'].apply(lambda d: determine_offerid_value(d) if (type(d) is dict) else ' ')

# %%
transcript.loc[:,'amount'] = transcript[transcript['event']=='transaction']['value'].apply(lambda d: d['amount'])

# %%
transcript.loc[:,'reward'] = transcript[transcript['event']=='offer completed']['value'].apply(lambda d: d['reward'])

# %%
transcript[transcript['event']=='offer completed'].head()
# Out:
#                                  person            event  \
# 12658  9fa9ae8f57894cc9a3b8a9bbe0fc1b2f  offer completed
# 12672  fe97aa22dd3e48c8b143116a8403dd52  offer completed
# 12679  629fc02d56414d91bca360decdfa9288  offer completed
# 12692  676506bad68e4161b9bbaffeb039626b  offer completed
# 12697  8f7dd3b2afe14c078eb4f6e6fe4ba97d  offer completed
#
#                                                    value  time  \
# 12658  {'offer_id': '2906b810c7d4411798c6938adc9daaa5...     0
# 12672  {'offer_id': 'fafdcd668e3743c1bb461111dcafc2a4...     0
# 12679  {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9...     0
# 12692  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd...     0
# 12697  {'offer_id': '4d5c57ea9a6940dd891ad53e9dbe8da0...     0
#
#                                offer_id  amount  reward
# 12658  2906b810c7d4411798c6938adc9daaa5     NaN     2.0
# 12672  fafdcd668e3743c1bb461111dcafc2a4     NaN     2.0
# 12679  9b98b8c7a33c4b65b9aebfe6a799e6d9     NaN     5.0
# 12692  ae264e3637204a6fb9bb56bc8210ddfd     NaN    10.0
# 12697  4d5c57ea9a6940dd891ad53e9dbe8da0     NaN    10.0

# %%
transcript[transcript['event']=='transaction'].head()
# Out:
#                                  person        event  \
# 12654  02c083884c7d45b39cc68e1314fec56c  transaction
# 12657  9fa9ae8f57894cc9a3b8a9bbe0fc1b2f  transaction
# 12659  54890f68699049c2a04d415abc25e717  transaction
# 12670  b2f1cd155b864803ad8334cdf13c4bd2  transaction
# 12671  fe97aa22dd3e48c8b143116a8403dd52  transaction
#
#                                 value  time offer_id  amount  reward
# 12654  {'amount': 0.8300000000000001}     0     None    0.83     NaN
# 12657               {'amount': 34.56}     0     None   34.56     NaN
# 12659               {'amount': 13.23}     0     None   13.23     NaN
# 12670               {'amount': 19.51}     0     None   19.51     NaN
# 12671               {'amount': 18.97}     0     None   18.97     NaN

# %% [markdown]
# # por aqui voy

# %%
single_client_transaction_log = transcript.loc[transcript['person'] == transcript.iloc[0,0]].sort_values('time')
single_client_transaction_log
# Out:
#                                   person            event  \
# 0       78afa995795e4d85b5d9ceeca43f5fef   offer received
# 15561   78afa995795e4d85b5d9ceeca43f5fef     offer viewed
# 47582   78afa995795e4d85b5d9ceeca43f5fef      transaction
# 47583   78afa995795e4d85b5d9ceeca43f5fef  offer completed
# 49502   78afa995795e4d85b5d9ceeca43f5fef      transaction
# 53176   78afa995795e4d85b5d9ceeca43f5fef   offer received
# 85291   78afa995795e4d85b5d9ceeca43f5fef     offer viewed
# 87134   78afa995795e4d85b5d9ceeca43f5fef      transaction
# 92104   78afa995795e4d85b5d9ceeca43f5fef      transaction
# 141566  78afa995795e4d85b5d9ceeca43f5fef      transaction
# 150598  78afa995795e4d85b5d9ceeca43f5fef   offer received
# 163375  78afa995795e4d85b5d9ceeca43f5fef     offer viewed
# 201572  78afa995795e4d85b5d9ceeca43f5fef   offer received
# 218393  78afa995795e4d85b5d9ceeca43f5fef      transaction
# 218394  78afa995795e4d85b5d9ceeca43f5fef  offer completed
# 218395  78afa995795e4d85b5d9ceeca43f5fef  offer completed
# 230412  78afa995795e4d85b5d9ceeca43f5fef      transaction
# 262138  78afa995795e4d85b5d9ceeca43f5fef     offer viewed
#
#                                                     value  time  \
# 0        {'offer id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'}     0
# 15561    {'offer id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'}     6
# 47582                                   {'amount': 19.89}   132
# 47583   {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9...   132
# 49502                                   {'amount': 17.78}   144
# 53176    {'offer id': '5a8bc65990b245e5a138643cd4eb9837'}   168
# 85291    {'offer id': '5a8bc65990b245e5a138643cd4eb9837'}   216
# 87134                                   {'amount': 19.67}   222
# 92104                                   {'amount': 29.72}   240
# 141566                                  {'amount': 23.93}   378
# 150598   {'offer id': 'ae264e3637204a6fb9bb56bc8210ddfd'}   408
# 163375   {'offer id': 'ae264e3637204a6fb9bb56bc8210ddfd'}   408
# 201572   {'offer id': 'f19421c1d4aa40978ebb69ca19b0e20d'}   504
# 218393                                  {'amount': 21.72}   510
# 218394  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd...   510
# 218395  {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d...   510
# 230412                                  {'amount': 26.56}   534
# 262138   {'offer id': 'f19421c1d4aa40978ebb69ca19b0e20d'}   582
#
#                                 offer_id  amount  reward
# 0       9b98b8c7a33c4b65b9aebfe6a799e6d9     NaN     NaN
# 15561   9b98b8c7a33c4b65b9aebfe6a799e6d9     NaN     NaN
# 47582                               None   19.89     NaN
# 47583   9b98b8c7a33c4b65b9aebfe6a799e6d9     NaN     5.0
# 49502                               None   17.78     NaN
# 53176   5a8bc65990b245e5a138643cd4eb9837     NaN     NaN
# 85291   5a8bc65990b245e5a138643cd4eb9837     NaN     NaN
# 87134                               None   19.67     NaN
# 92104                               None   29.72     NaN
# 141566                              None   23.93     NaN
# 150598  ae264e3637204a6fb9bb56bc8210ddfd     NaN     NaN
# 163375  ae264e3637204a6fb9bb56bc8210ddfd     NaN     NaN
# 201572  f19421c1d4aa40978ebb69ca19b0e20d     NaN     NaN
# 218393                              None   21.72     NaN
# 218394  ae264e3637204a6fb9bb56bc8210ddfd     NaN    10.0
# 218395  f19421c1d4aa40978ebb69ca19b0e20d     NaN     5.0
# 230412                              None   26.56     NaN
# 262138  f19421c1d4aa40978ebb69ca19b0e20d     NaN     NaN

# %%
relation_event_person = transcript.groupby(['person', 'event'])['time'].count()
relation_event_person.head(20)
# Out:
# person                            event
# 0009655768c64bdeb2e877511632db8f  offer completed     3
#                                   offer received      5
#                                   offer viewed        4
#                                   transaction         8
# 00116118485d4dfda04fdbaba9a87b5c  offer received      2
#                                   offer viewed        2
#                                   transaction         3
# 0011e0d4e6b944f998e987f904e8c1e5  offer completed     3
#                                   offer received      5
#                                   offer viewed        5
#                                   transaction         5
# 0020c2b971eb4e9188eac86d93036a77  offer completed     3
#                                   offer received      5
#                                   offer viewed        3
#                                   transaction         8
# 0020ccbbb6d84e358d3414a3ff76cffd  offer completed     3
#                                   offer received      4
#                                   offer viewed        4
#                                   transaction        12
# 003d66b6608740288d6cc97a6903f4f0  offer completed     3
# Name: time, dtype: int64

# %%
transcript.iloc[0,0]
# Out:
# '78afa995795e4d85b5d9ceeca43f5fef'

# %%
portfolio_2_merge = portfolio[['reward','difficulty','duration','offer_type','offer_id']]
transactions_offers   =  pd.merge( transcript , portfolio_2_merge , on='offer_id', how='left')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-513-a9ec2516b4e7> in <module>
# ----> 1 portfolio_2_merge = portfolio[['reward','difficulty','duration','offer_type','offer_id']]
#       2 transactions_offers   =  pd.merge( transcript , portfolio_2_merge.loc[:,['person', 'offer_id', 'time']] , on='offer_id', how='left')
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2804             if is_iterator(key):
#    2805                 key = list(key)
# -> 2806             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2807
#    2808         # take() does not accept boolean indexers
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1551
#    1552         self._validate_read_indexer(
# -> 1553             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1554         )
#    1555         return keyarr, indexer
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1644             if not (self.name == "loc" and not raise_missing):
#    1645                 not_found = list(set(key) - set(ax))
# -> 1646                 raise KeyError(f"{not_found} not in index")
#    1647
#    1648             # we skip the warning on Categorical/Interval
#
# KeyError: "['offer_id'] not in index"

# %%
transactions_offers.head(100)
# Out:
#                               person           event  \
# 0   78afa995795e4d85b5d9ceeca43f5fef  offer received
# 1   a03223e636434f42ac4c3df47e8bac43  offer received
# 2   e2127556f4f64592b11af22de27a7932  offer received
# 3   8ec6ce2a7e7949b1bf142def7d0e0586  offer received
# 4   68617ca6246f4fbc85e91a2a49552598  offer received
# ..                               ...             ...
# 95  7c8479d8241344f6a0c306621e191c75  offer received
# 96  5404741ead9442bdbd4b9aa2273e85af  offer received
# 97  81e9ad5fa55a4884b65e01a5db8f1b4e  offer received
# 98  ed46fca6de7042478b411690878dc069  offer received
# 99  37a97f6e09784a07bbb67bc6539f1a00  offer received
#
#                                                value  time  \
# 0   {'offer id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'}     0
# 1   {'offer id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'}     0
# 2   {'offer id': '2906b810c7d4411798c6938adc9daaa5'}     0
# 3   {'offer id': 'fafdcd668e3743c1bb461111dcafc2a4'}     0
# 4   {'offer id': '4d5c57ea9a6940dd891ad53e9dbe8da0'}     0
# ..                                               ...   ...
# 95  {'offer id': '5a8bc65990b245e5a138643cd4eb9837'}     0
# 96  {'offer id': '2298d6c36e964ae4a3e7e9706d1fb8c2'}     0
# 97  {'offer id': 'ae264e3637204a6fb9bb56bc8210ddfd'}     0
# 98  {'offer id': '2906b810c7d4411798c6938adc9daaa5'}     0
# 99  {'offer id': '3f207df678b143eea3cee63160fa8bed'}     0
#
#                             offer_id  reward  difficulty  duration  \
# 0   9b98b8c7a33c4b65b9aebfe6a799e6d9     5.0         5.0       7.0
# 1   0b1e1539f2cc45b7b9fa7c272da2e1d7     5.0        20.0      10.0
# 2   2906b810c7d4411798c6938adc9daaa5     2.0        10.0       7.0
# 3   fafdcd668e3743c1bb461111dcafc2a4     2.0        10.0      10.0
# 4   4d5c57ea9a6940dd891ad53e9dbe8da0    10.0        10.0       5.0
# ..                               ...     ...         ...       ...
# 95  5a8bc65990b245e5a138643cd4eb9837     0.0         0.0       3.0
# 96  2298d6c36e964ae4a3e7e9706d1fb8c2     3.0         7.0       7.0
# 97  ae264e3637204a6fb9bb56bc8210ddfd    10.0        10.0       7.0
# 98  2906b810c7d4411798c6938adc9daaa5     2.0        10.0       7.0
# 99  3f207df678b143eea3cee63160fa8bed     0.0         0.0       4.0
#
#        offer_type
# 0            bogo
# 1        discount
# 2        discount
# 3        discount
# 4            bogo
# ..            ...
# 95  informational
# 96       discount
# 97           bogo
# 98       discount
# 99  informational
#
# [100 rows x 9 columns]

# %%
offers_viewed   = transactions_offers.loc[ transactions_offers['event'] == 'offer viewed',:]

# %%
offers_viewed.set_index(['person','offer_id'])
# Out:
#                                                                           event  \
# person                           offer_id
# 389bc3fa690240e798340f5a15918d5c f19421c1d4aa40978ebb69ca19b0e20d  offer viewed
# d1ede868e29245ea91818a903fec04c6 5a8bc65990b245e5a138643cd4eb9837  offer viewed
# 102e9454054946fda62242d2e176fdce 4d5c57ea9a6940dd891ad53e9dbe8da0  offer viewed
# 02c083884c7d45b39cc68e1314fec56c ae264e3637204a6fb9bb56bc8210ddfd  offer viewed
# be8a5d1981a2458d90b255ddc7e0d174 5a8bc65990b245e5a138643cd4eb9837  offer viewed
# ...                                                                         ...
# d56386cf344c4829bbf420d1895dca37 5a8bc65990b245e5a138643cd4eb9837  offer viewed
# 9b51e8797290403b90d09d864dec4b94 3f207df678b143eea3cee63160fa8bed  offer viewed
# 84fb57a7fe8045a8bf6236738ee73a0f 5a8bc65990b245e5a138643cd4eb9837  offer viewed
# abc4359eb34e4e2ca2349da2ddf771b6 3f207df678b143eea3cee63160fa8bed  offer viewed
# 8dda575c2a1d44b9ac8e8b07b93d1f8e 0b1e1539f2cc45b7b9fa7c272da2e1d7  offer viewed
#
#                                                                                                               value  \
# person                           offer_id
# 389bc3fa690240e798340f5a15918d5c f19421c1d4aa40978ebb69ca19b0e20d  {'offer id': 'f19421c1d4aa40978ebb69ca19b0e20d'}
# d1ede868e29245ea91818a903fec04c6 5a8bc65990b245e5a138643cd4eb9837  {'offer id': '5a8bc65990b245e5a138643cd4eb9837'}
# 102e9454054946fda62242d2e176fdce 4d5c57ea9a6940dd891ad53e9dbe8da0  {'offer id': '4d5c57ea9a6940dd891ad53e9dbe8da0'}
# 02c083884c7d45b39cc68e1314fec56c ae264e3637204a6fb9bb56bc8210ddfd  {'offer id': 'ae264e3637204a6fb9bb56bc8210ddfd'}
# be8a5d1981a2458d90b255ddc7e0d174 5a8bc65990b245e5a138643cd4eb9837  {'offer id': '5a8bc65990b245e5a138643cd4eb9837'}
# ...                                                                                                             ...
# d56386cf344c4829bbf420d1895dca37 5a8bc65990b245e5a138643cd4eb9837  {'offer id': '5a8bc65990b245e5a138643cd4eb9837'}
# 9b51e8797290403b90d09d864dec4b94 3f207df678b143eea3cee63160fa8bed  {'offer id': '3f207df678b143eea3cee63160fa8bed'}
# 84fb57a7fe8045a8bf6236738ee73a0f 5a8bc65990b245e5a138643cd4eb9837  {'offer id': '5a8bc65990b245e5a138643cd4eb9837'}
# abc4359eb34e4e2ca2349da2ddf771b6 3f207df678b143eea3cee63160fa8bed  {'offer id': '3f207df678b143eea3cee63160fa8bed'}
# 8dda575c2a1d44b9ac8e8b07b93d1f8e 0b1e1539f2cc45b7b9fa7c272da2e1d7  {'offer id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'}
#
#                                                                    time  \
# person                           offer_id
# 389bc3fa690240e798340f5a15918d5c f19421c1d4aa40978ebb69ca19b0e20d     0
# d1ede868e29245ea91818a903fec04c6 5a8bc65990b245e5a138643cd4eb9837     0
# 102e9454054946fda62242d2e176fdce 4d5c57ea9a6940dd891ad53e9dbe8da0     0
# 02c083884c7d45b39cc68e1314fec56c ae264e3637204a6fb9bb56bc8210ddfd     0
# be8a5d1981a2458d90b255ddc7e0d174 5a8bc65990b245e5a138643cd4eb9837     0
# ...                                                                 ...
# d56386cf344c4829bbf420d1895dca37 5a8bc65990b245e5a138643cd4eb9837   714
# 9b51e8797290403b90d09d864dec4b94 3f207df678b143eea3cee63160fa8bed   714
# 84fb57a7fe8045a8bf6236738ee73a0f 5a8bc65990b245e5a138643cd4eb9837   714
# abc4359eb34e4e2ca2349da2ddf771b6 3f207df678b143eea3cee63160fa8bed   714
# 8dda575c2a1d44b9ac8e8b07b93d1f8e 0b1e1539f2cc45b7b9fa7c272da2e1d7   714
#
#                                                                    reward  \
# person                           offer_id
# 389bc3fa690240e798340f5a15918d5c f19421c1d4aa40978ebb69ca19b0e20d     5.0
# d1ede868e29245ea91818a903fec04c6 5a8bc65990b245e5a138643cd4eb9837     0.0
# 102e9454054946fda62242d2e176fdce 4d5c57ea9a6940dd891ad53e9dbe8da0    10.0
# 02c083884c7d45b39cc68e1314fec56c ae264e3637204a6fb9bb56bc8210ddfd    10.0
# be8a5d1981a2458d90b255ddc7e0d174 5a8bc65990b245e5a138643cd4eb9837     0.0
# ...                                                                   ...
# d56386cf344c4829bbf420d1895dca37 5a8bc65990b245e5a138643cd4eb9837     0.0
# 9b51e8797290403b90d09d864dec4b94 3f207df678b143eea3cee63160fa8bed     0.0
# 84fb57a7fe8045a8bf6236738ee73a0f 5a8bc65990b245e5a138643cd4eb9837     0.0
# abc4359eb34e4e2ca2349da2ddf771b6 3f207df678b143eea3cee63160fa8bed     0.0
# 8dda575c2a1d44b9ac8e8b07b93d1f8e 0b1e1539f2cc45b7b9fa7c272da2e1d7     5.0
#
#                                                                    difficulty  \
# person                           offer_id
# 389bc3fa690240e798340f5a15918d5c f19421c1d4aa40978ebb69ca19b0e20d         5.0
# d1ede868e29245ea91818a903fec04c6 5a8bc65990b245e5a138643cd4eb9837         0.0
# 102e9454054946fda62242d2e176fdce 4d5c57ea9a6940dd891ad53e9dbe8da0        10.0
# 02c083884c7d45b39cc68e1314fec56c ae264e3637204a6fb9bb56bc8210ddfd        10.0
# be8a5d1981a2458d90b255ddc7e0d174 5a8bc65990b245e5a138643cd4eb9837         0.0
# ...                                                                       ...
# d56386cf344c4829bbf420d1895dca37 5a8bc65990b245e5a138643cd4eb9837         0.0
# 9b51e8797290403b90d09d864dec4b94 3f207df678b143eea3cee63160fa8bed         0.0
# 84fb57a7fe8045a8bf6236738ee73a0f 5a8bc65990b245e5a138643cd4eb9837         0.0
# abc4359eb34e4e2ca2349da2ddf771b6 3f207df678b143eea3cee63160fa8bed         0.0
# 8dda575c2a1d44b9ac8e8b07b93d1f8e 0b1e1539f2cc45b7b9fa7c272da2e1d7        20.0
#
#                                                                    duration  \
# person                           offer_id
# 389bc3fa690240e798340f5a15918d5c f19421c1d4aa40978ebb69ca19b0e20d       5.0
# d1ede868e29245ea91818a903fec04c6 5a8bc65990b245e5a138643cd4eb9837       3.0
# 102e9454054946fda62242d2e176fdce 4d5c57ea9a6940dd891ad53e9dbe8da0       5.0
# 02c083884c7d45b39cc68e1314fec56c ae264e3637204a6fb9bb56bc8210ddfd       7.0
# be8a5d1981a2458d90b255ddc7e0d174 5a8bc65990b245e5a138643cd4eb9837       3.0
# ...                                                                     ...
# d56386cf344c4829bbf420d1895dca37 5a8bc65990b245e5a138643cd4eb9837       3.0
# 9b51e8797290403b90d09d864dec4b94 3f207df678b143eea3cee63160fa8bed       4.0
# 84fb57a7fe8045a8bf6236738ee73a0f 5a8bc65990b245e5a138643cd4eb9837       3.0
# abc4359eb34e4e2ca2349da2ddf771b6 3f207df678b143eea3cee63160fa8bed       4.0
# 8dda575c2a1d44b9ac8e8b07b93d1f8e 0b1e1539f2cc45b7b9fa7c272da2e1d7      10.0
#
#                                                                       offer_type
# person                           offer_id
# 389bc3fa690240e798340f5a15918d5c f19421c1d4aa40978ebb69ca19b0e20d           bogo
# d1ede868e29245ea91818a903fec04c6 5a8bc65990b245e5a138643cd4eb9837  informational
# 102e9454054946fda62242d2e176fdce 4d5c57ea9a6940dd891ad53e9dbe8da0           bogo
# 02c083884c7d45b39cc68e1314fec56c ae264e3637204a6fb9bb56bc8210ddfd           bogo
# be8a5d1981a2458d90b255ddc7e0d174 5a8bc65990b245e5a138643cd4eb9837  informational
# ...                                                                          ...
# d56386cf344c4829bbf420d1895dca37 5a8bc65990b245e5a138643cd4eb9837  informational
# 9b51e8797290403b90d09d864dec4b94 3f207df678b143eea3cee63160fa8bed  informational
# 84fb57a7fe8045a8bf6236738ee73a0f 5a8bc65990b245e5a138643cd4eb9837  informational
# abc4359eb34e4e2ca2349da2ddf771b6 3f207df678b143eea3cee63160fa8bed  informational
# 8dda575c2a1d44b9ac8e8b07b93d1f8e 0b1e1539f2cc45b7b9fa7c272da2e1d7       discount
#
# [57725 rows x 7 columns]

# %%
offers_viewed.sort_values(by=['person','time'])
# Out:
#                                   person         event  \
# 77705   0009655768c64bdeb2e877511632db8f  offer viewed
# 139992  0009655768c64bdeb2e877511632db8f  offer viewed
# 187554  0009655768c64bdeb2e877511632db8f  offer viewed
# 233413  0009655768c64bdeb2e877511632db8f  offer viewed
# 85769   00116118485d4dfda04fdbaba9a87b5c  offer viewed
# ...                                  ...           ...
# 69626   ffff82501cea40309d5fdd7edcca4a07  offer viewed
# 133074  ffff82501cea40309d5fdd7edcca4a07  offer viewed
# 168022  ffff82501cea40309d5fdd7edcca4a07  offer viewed
# 230690  ffff82501cea40309d5fdd7edcca4a07  offer viewed
# 262475  ffff82501cea40309d5fdd7edcca4a07  offer viewed
#
#                                                    value  time  \
# 77705   {'offer id': '5a8bc65990b245e5a138643cd4eb9837'}   192
# 139992  {'offer id': '3f207df678b143eea3cee63160fa8bed'}   372
# 187554  {'offer id': 'f19421c1d4aa40978ebb69ca19b0e20d'}   456
# 233413  {'offer id': 'fafdcd668e3743c1bb461111dcafc2a4'}   540
# 85769   {'offer id': 'f19421c1d4aa40978ebb69ca19b0e20d'}   216
# ...                                                  ...   ...
# 69626   {'offer id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'}   174
# 133074  {'offer id': '2906b810c7d4411798c6938adc9daaa5'}   354
# 168022  {'offer id': '2906b810c7d4411798c6938adc9daaa5'}   414
# 230690  {'offer id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'}   534
# 262475  {'offer id': '2906b810c7d4411798c6938adc9daaa5'}   582
#
#                                 offer_id  reward  difficulty  duration  \
# 77705   5a8bc65990b245e5a138643cd4eb9837     0.0         0.0       3.0
# 139992  3f207df678b143eea3cee63160fa8bed     0.0         0.0       4.0
# 187554  f19421c1d4aa40978ebb69ca19b0e20d     5.0         5.0       5.0
# 233413  fafdcd668e3743c1bb461111dcafc2a4     2.0        10.0      10.0
# 85769   f19421c1d4aa40978ebb69ca19b0e20d     5.0         5.0       5.0
# ...                                  ...     ...         ...       ...
# 69626   0b1e1539f2cc45b7b9fa7c272da2e1d7     5.0        20.0      10.0
# 133074  2906b810c7d4411798c6938adc9daaa5     2.0        10.0       7.0
# 168022  2906b810c7d4411798c6938adc9daaa5     2.0        10.0       7.0
# 230690  9b98b8c7a33c4b65b9aebfe6a799e6d9     5.0         5.0       7.0
# 262475  2906b810c7d4411798c6938adc9daaa5     2.0        10.0       7.0
#
#            offer_type
# 77705   informational
# 139992  informational
# 187554           bogo
# 233413       discount
# 85769            bogo
# ...               ...
# 69626        discount
# 133074       discount
# 168022       discount
# 230690           bogo
# 262475       discount
#
# [57725 rows x 9 columns]

# %% [markdown]
# When analysing the data set, it can be noticed that a customer can see an offer more than once and that a transaction is recorded in each case. See above person **ffff82501cea40309d5fdd7edcca4a07** offer_id **2906b810c7d4411798c6938adc9daaa5**

# %%
offers_viewed.shape
# Out:
# (57725, 9)

# %% [markdown]
# ### Let us now look at the completed offers, it is important to note that this includes all completed offers regardless of whether they were seen or not previously

# %%
offers_completed = transactions_offers.loc[ transactions_offers['event'] == 'offer completed',:]

# %%
offers_completed.set_index('person','offer_id')
offers_completed.head()
# Out:
#                                  person            event  \
# 12658  9fa9ae8f57894cc9a3b8a9bbe0fc1b2f  offer completed
# 12672  fe97aa22dd3e48c8b143116a8403dd52  offer completed
# 12679  629fc02d56414d91bca360decdfa9288  offer completed
# 12692  676506bad68e4161b9bbaffeb039626b  offer completed
# 12697  8f7dd3b2afe14c078eb4f6e6fe4ba97d  offer completed
#
#                                                    value  time  \
# 12658  {'offer_id': '2906b810c7d4411798c6938adc9daaa5...     0
# 12672  {'offer_id': 'fafdcd668e3743c1bb461111dcafc2a4...     0
# 12679  {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9...     0
# 12692  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd...     0
# 12697  {'offer_id': '4d5c57ea9a6940dd891ad53e9dbe8da0...     0
#
#                                offer_id  reward  difficulty  duration  \
# 12658  2906b810c7d4411798c6938adc9daaa5     2.0        10.0       7.0
# 12672  fafdcd668e3743c1bb461111dcafc2a4     2.0        10.0      10.0
# 12679  9b98b8c7a33c4b65b9aebfe6a799e6d9     5.0         5.0       7.0
# 12692  ae264e3637204a6fb9bb56bc8210ddfd    10.0        10.0       7.0
# 12697  4d5c57ea9a6940dd891ad53e9dbe8da0    10.0        10.0       5.0
#
#       offer_type
# 12658   discount
# 12672   discount
# 12679       bogo
# 12692       bogo
# 12697       bogo

# %%
offers_completed.sort_values(by=['person','time'])
# Out:
#                                   person            event  \
# 168413  0009655768c64bdeb2e877511632db8f  offer completed
# 228423  0009655768c64bdeb2e877511632db8f  offer completed
# 258884  0009655768c64bdeb2e877511632db8f  offer completed
# 95422   0011e0d4e6b944f998e987f904e8c1e5  offer completed
# 258980  0011e0d4e6b944f998e987f904e8c1e5  offer completed
# ...                                  ...              ...
# 79668   ffff82501cea40309d5fdd7edcca4a07  offer completed
# 143788  ffff82501cea40309d5fdd7edcca4a07  offer completed
# 168024  ffff82501cea40309d5fdd7edcca4a07  offer completed
# 214717  ffff82501cea40309d5fdd7edcca4a07  offer completed
# 258362  ffff82501cea40309d5fdd7edcca4a07  offer completed
#
#                                                     value  time  \
# 168413  {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d...   414
# 228423  {'offer_id': 'fafdcd668e3743c1bb461111dcafc2a4...   528
# 258884  {'offer_id': '2906b810c7d4411798c6938adc9daaa5...   576
# 95422   {'offer_id': '2298d6c36e964ae4a3e7e9706d1fb8c2...   252
# 258980  {'offer_id': '0b1e1539f2cc45b7b9fa7c272da2e1d7...   576
# ...                                                   ...   ...
# 79668   {'offer_id': '0b1e1539f2cc45b7b9fa7c272da2e1d7...   198
# 143788  {'offer_id': '2906b810c7d4411798c6938adc9daaa5...   384
# 168024  {'offer_id': '2906b810c7d4411798c6938adc9daaa5...   414
# 214717  {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9...   504
# 258362  {'offer_id': '2906b810c7d4411798c6938adc9daaa5...   576
#
#                                 offer_id  reward  difficulty  duration  \
# 168413  f19421c1d4aa40978ebb69ca19b0e20d     5.0         5.0       5.0
# 228423  fafdcd668e3743c1bb461111dcafc2a4     2.0        10.0      10.0
# 258884  2906b810c7d4411798c6938adc9daaa5     2.0        10.0       7.0
# 95422   2298d6c36e964ae4a3e7e9706d1fb8c2     3.0         7.0       7.0
# 258980  0b1e1539f2cc45b7b9fa7c272da2e1d7     5.0        20.0      10.0
# ...                                  ...     ...         ...       ...
# 79668   0b1e1539f2cc45b7b9fa7c272da2e1d7     5.0        20.0      10.0
# 143788  2906b810c7d4411798c6938adc9daaa5     2.0        10.0       7.0
# 168024  2906b810c7d4411798c6938adc9daaa5     2.0        10.0       7.0
# 214717  9b98b8c7a33c4b65b9aebfe6a799e6d9     5.0         5.0       7.0
# 258362  2906b810c7d4411798c6938adc9daaa5     2.0        10.0       7.0
#
#        offer_type
# 168413       bogo
# 228423   discount
# 258884   discount
# 95422    discount
# 258980   discount
# ...           ...
# 79668    discount
# 143788   discount
# 168024   discount
# 214717       bogo
# 258362   discount
#
# [33579 rows x 9 columns]

# %% [markdown]
# ### Now, let's select only those offers that were completed after having been viewed previously

# %%
viewed_and_completed = pd.merge ( offers_completed , offers_viewed.loc[:,['person', 'offer_id']], on=['person','offer_id'])

# %%
viewed_and_completed.sort_values(by=['person'])
viewed_and_completed.head(10)
# Out:
#                              person            event  \
# 0  9fa9ae8f57894cc9a3b8a9bbe0fc1b2f  offer completed
# 1  fe97aa22dd3e48c8b143116a8403dd52  offer completed
# 2  629fc02d56414d91bca360decdfa9288  offer completed
# 3  676506bad68e4161b9bbaffeb039626b  offer completed
# 4  8f7dd3b2afe14c078eb4f6e6fe4ba97d  offer completed
# 5  227f2d69e46a4899b70d48182822cff6  offer completed
# 6  bb0f25e23a4c4de6a645527c275cd594  offer completed
# 7  bb0f25e23a4c4de6a645527c275cd594  offer completed
# 8  bb0f25e23a4c4de6a645527c275cd594  offer completed
# 9  bb0f25e23a4c4de6a645527c275cd594  offer completed
#
#                                                value  time  \
# 0  {'offer_id': '2906b810c7d4411798c6938adc9daaa5...     0
# 1  {'offer_id': 'fafdcd668e3743c1bb461111dcafc2a4...     0
# 2  {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9...     0
# 3  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd...     0
# 4  {'offer_id': '4d5c57ea9a6940dd891ad53e9dbe8da0...     0
# 5  {'offer_id': '4d5c57ea9a6940dd891ad53e9dbe8da0...     0
# 6  {'offer_id': '2298d6c36e964ae4a3e7e9706d1fb8c2...     0
# 7  {'offer_id': '2298d6c36e964ae4a3e7e9706d1fb8c2...     0
# 8  {'offer_id': '2298d6c36e964ae4a3e7e9706d1fb8c2...   654
# 9  {'offer_id': '2298d6c36e964ae4a3e7e9706d1fb8c2...   654
#
#                            offer_id  reward  difficulty  duration offer_type
# 0  2906b810c7d4411798c6938adc9daaa5     2.0        10.0       7.0   discount
# 1  fafdcd668e3743c1bb461111dcafc2a4     2.0        10.0      10.0   discount
# 2  9b98b8c7a33c4b65b9aebfe6a799e6d9     5.0         5.0       7.0       bogo
# 3  ae264e3637204a6fb9bb56bc8210ddfd    10.0        10.0       7.0       bogo
# 4  4d5c57ea9a6940dd891ad53e9dbe8da0    10.0        10.0       5.0       bogo
# 5  4d5c57ea9a6940dd891ad53e9dbe8da0    10.0        10.0       5.0       bogo
# 6  2298d6c36e964ae4a3e7e9706d1fb8c2     3.0         7.0       7.0   discount
# 7  2298d6c36e964ae4a3e7e9706d1fb8c2     3.0         7.0       7.0   discount
# 8  2298d6c36e964ae4a3e7e9706d1fb8c2     3.0         7.0       7.0   discount
# 9  2298d6c36e964ae4a3e7e9706d1fb8c2     3.0         7.0       7.0   discount

# %%
viewed_and_completed.shape
# Out:
# (37952, 9)

# %%
viewed_and_completed.drop_duplicates(['person', 'offer_id', 'time'])
# Out:
#                                  person            event  \
# 0      9fa9ae8f57894cc9a3b8a9bbe0fc1b2f  offer completed
# 1      fe97aa22dd3e48c8b143116a8403dd52  offer completed
# 2      629fc02d56414d91bca360decdfa9288  offer completed
# 3      676506bad68e4161b9bbaffeb039626b  offer completed
# 4      8f7dd3b2afe14c078eb4f6e6fe4ba97d  offer completed
# ...                                 ...              ...
# 37946  452cdae2c68e4732a4177d3929562690  offer completed
# 37947  0c027f5f34dd4b9eba0a25785c611273  offer completed
# 37948  a6f84f4e976f44508c358cc9aba6d2b3  offer completed
# 37950  8431c16f8e1d440880db371a68f82dd0  offer completed
# 37951  24f56b5e1849462093931b164eb803b5  offer completed
#
#                                                    value  time  \
# 0      {'offer_id': '2906b810c7d4411798c6938adc9daaa5...     0
# 1      {'offer_id': 'fafdcd668e3743c1bb461111dcafc2a4...     0
# 2      {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9...     0
# 3      {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd...     0
# 4      {'offer_id': '4d5c57ea9a6940dd891ad53e9dbe8da0...     0
# ...                                                  ...   ...
# 37946  {'offer_id': 'fafdcd668e3743c1bb461111dcafc2a4...   714
# 37947  {'offer_id': '2298d6c36e964ae4a3e7e9706d1fb8c2...   714
# 37948  {'offer_id': '2298d6c36e964ae4a3e7e9706d1fb8c2...   714
# 37950  {'offer_id': 'fafdcd668e3743c1bb461111dcafc2a4...   714
# 37951  {'offer_id': 'fafdcd668e3743c1bb461111dcafc2a4...   714
#
#                                offer_id  reward  difficulty  duration  \
# 0      2906b810c7d4411798c6938adc9daaa5     2.0        10.0       7.0
# 1      fafdcd668e3743c1bb461111dcafc2a4     2.0        10.0      10.0
# 2      9b98b8c7a33c4b65b9aebfe6a799e6d9     5.0         5.0       7.0
# 3      ae264e3637204a6fb9bb56bc8210ddfd    10.0        10.0       7.0
# 4      4d5c57ea9a6940dd891ad53e9dbe8da0    10.0        10.0       5.0
# ...                                 ...     ...         ...       ...
# 37946  fafdcd668e3743c1bb461111dcafc2a4     2.0        10.0      10.0
# 37947  2298d6c36e964ae4a3e7e9706d1fb8c2     3.0         7.0       7.0
# 37948  2298d6c36e964ae4a3e7e9706d1fb8c2     3.0         7.0       7.0
# 37950  fafdcd668e3743c1bb461111dcafc2a4     2.0        10.0      10.0
# 37951  fafdcd668e3743c1bb461111dcafc2a4     2.0        10.0      10.0
#
#       offer_type
# 0       discount
# 1       discount
# 2           bogo
# 3           bogo
# 4           bogo
# ...          ...
# 37946   discount
# 37947   discount
# 37948   discount
# 37950   discount
# 37951   discount
#
# [28382 rows x 9 columns]

# %%
transactions_offers[ (transactions_offers['person']=='bb0f25e23a4c4de6a645527c275cd594')   ]
# Out:
#                                   person            event  \
# 317     bb0f25e23a4c4de6a645527c275cd594   offer received
# 12720   bb0f25e23a4c4de6a645527c275cd594      transaction
# 12721   bb0f25e23a4c4de6a645527c275cd594  offer completed
# 40812   bb0f25e23a4c4de6a645527c275cd594     offer viewed
# 52288   bb0f25e23a4c4de6a645527c275cd594      transaction
# 53492   bb0f25e23a4c4de6a645527c275cd594   offer received
# 74855   bb0f25e23a4c4de6a645527c275cd594     offer viewed
# 97732   bb0f25e23a4c4de6a645527c275cd594      transaction
# 97733   bb0f25e23a4c4de6a645527c275cd594  offer completed
# 150932  bb0f25e23a4c4de6a645527c275cd594   offer received
# 163478  bb0f25e23a4c4de6a645527c275cd594     offer viewed
# 184965  bb0f25e23a4c4de6a645527c275cd594      transaction
# 184966  bb0f25e23a4c4de6a645527c275cd594  offer completed
# 193250  bb0f25e23a4c4de6a645527c275cd594      transaction
# 201883  bb0f25e23a4c4de6a645527c275cd594   offer received
# 221968  bb0f25e23a4c4de6a645527c275cd594     offer viewed
# 232934  bb0f25e23a4c4de6a645527c275cd594      transaction
# 232935  bb0f25e23a4c4de6a645527c275cd594  offer completed
# 245438  bb0f25e23a4c4de6a645527c275cd594   offer received
# 262223  bb0f25e23a4c4de6a645527c275cd594     offer viewed
# 291554  bb0f25e23a4c4de6a645527c275cd594      transaction
# 291555  bb0f25e23a4c4de6a645527c275cd594  offer completed
# 300686  bb0f25e23a4c4de6a645527c275cd594      transaction
#
#                                                     value  time  \
# 317      {'offer id': '2298d6c36e964ae4a3e7e9706d1fb8c2'}     0
# 12720                                   {'amount': 28.08}     0
# 12721   {'offer_id': '2298d6c36e964ae4a3e7e9706d1fb8c2...     0
# 40812    {'offer id': '2298d6c36e964ae4a3e7e9706d1fb8c2'}    96
# 52288                                   {'amount': 21.62}   162
# 53492    {'offer id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'}   168
# 74855    {'offer id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'}   186
# 97732                                   {'amount': 35.95}   264
# 97733   {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9...   264
# 150932   {'offer id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'}   408
# 163478   {'offer id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'}   408
# 184965                                  {'amount': 25.18}   450
# 184966  {'offer_id': '0b1e1539f2cc45b7b9fa7c272da2e1d7...   450
# 193250                                   {'amount': 24.4}   474
# 201883   {'offer id': 'ae264e3637204a6fb9bb56bc8210ddfd'}   504
# 221968   {'offer id': 'ae264e3637204a6fb9bb56bc8210ddfd'}   516
# 232934                                  {'amount': 19.46}   540
# 232935  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd...   540
# 245438   {'offer id': '2298d6c36e964ae4a3e7e9706d1fb8c2'}   576
# 262223   {'offer id': '2298d6c36e964ae4a3e7e9706d1fb8c2'}   582
# 291554                                  {'amount': 17.25}   654
# 291555  {'offer_id': '2298d6c36e964ae4a3e7e9706d1fb8c2...   654
# 300686                                  {'amount': 16.96}   690
#
#                                 offer_id  reward  difficulty  duration  \
# 317     2298d6c36e964ae4a3e7e9706d1fb8c2     3.0         7.0       7.0
# 12720                               None     NaN         NaN       NaN
# 12721   2298d6c36e964ae4a3e7e9706d1fb8c2     3.0         7.0       7.0
# 40812   2298d6c36e964ae4a3e7e9706d1fb8c2     3.0         7.0       7.0
# 52288                               None     NaN         NaN       NaN
# 53492   9b98b8c7a33c4b65b9aebfe6a799e6d9     5.0         5.0       7.0
# 74855   9b98b8c7a33c4b65b9aebfe6a799e6d9     5.0         5.0       7.0
# 97732                               None     NaN         NaN       NaN
# 97733   9b98b8c7a33c4b65b9aebfe6a799e6d9     5.0         5.0       7.0
# 150932  0b1e1539f2cc45b7b9fa7c272da2e1d7     5.0        20.0      10.0
# 163478  0b1e1539f2cc45b7b9fa7c272da2e1d7     5.0        20.0      10.0
# 184965                              None     NaN         NaN       NaN
# 184966  0b1e1539f2cc45b7b9fa7c272da2e1d7     5.0        20.0      10.0
# 193250                              None     NaN         NaN       NaN
# 201883  ae264e3637204a6fb9bb56bc8210ddfd    10.0        10.0       7.0
# 221968  ae264e3637204a6fb9bb56bc8210ddfd    10.0        10.0       7.0
# 232934                              None     NaN         NaN       NaN
# 232935  ae264e3637204a6fb9bb56bc8210ddfd    10.0        10.0       7.0
# 245438  2298d6c36e964ae4a3e7e9706d1fb8c2     3.0         7.0       7.0
# 262223  2298d6c36e964ae4a3e7e9706d1fb8c2     3.0         7.0       7.0
# 291554                              None     NaN         NaN       NaN
# 291555  2298d6c36e964ae4a3e7e9706d1fb8c2     3.0         7.0       7.0
# 300686                              None     NaN         NaN       NaN
#
#        offer_type
# 317      discount
# 12720         NaN
# 12721    discount
# 40812    discount
# 52288         NaN
# 53492        bogo
# 74855        bogo
# 97732         NaN
# 97733        bogo
# 150932   discount
# 163478   discount
# 184965        NaN
# 184966   discount
# 193250        NaN
# 201883       bogo
# 221968       bogo
# 232934        NaN
# 232935       bogo
# 245438   discount
# 262223   discount
# 291554        NaN
# 291555   discount
# 300686        NaN

# %% [markdown]
# ### Let us now select the people who completed an offer after seeing it

# %%
poi_s = df_responded['person'].unique()
persons_of_interest = pd.DataFrame({'id':poi_s})

# %%
persons_of_interest.head()
# Out:
#                                  id
# 0  9fa9ae8f57894cc9a3b8a9bbe0fc1b2f
# 1  fe97aa22dd3e48c8b143116a8403dd52
# 2  629fc02d56414d91bca360decdfa9288
# 3  676506bad68e4161b9bbaffeb039626b
# 4  8f7dd3b2afe14c078eb4f6e6fe4ba97d

# %%
persons_of_interest.shape
# Out:
# (12202, 1)

# %%
profile.head()
# Out:
#   gender  age                                id  became_member_on    income
# 0   None  118  68be06ca386d4c31939f3a4f0e3dd783          20170212       NaN
# 1      F   55  0610b486422d4921ae7d2bf64640c50b          20170715  112000.0
# 2   None  118  38fe809add3b4fcf9315a9694bb96ff5          20180712       NaN
# 3      F   75  78afa995795e4d85b5d9ceeca43f5fef          20170509  100000.0
# 4   None  118  a03223e636434f42ac4c3df47e8bac43          20170804       NaN

# %%
profile.shape
# Out:
# (17000, 5)

# %%
profiles_of_interest =  pd.merge (persons_of_interest,profile,on='id')

# %%
profiles_of_interest.sort_values(by=['id'])
profiles_of_interest.head(10)
# Out:
#                                  id gender  age  became_member_on    income
# 0  9fa9ae8f57894cc9a3b8a9bbe0fc1b2f      M   42          20160117   96000.0
# 1  fe97aa22dd3e48c8b143116a8403dd52      F   39          20171217   67000.0
# 2  629fc02d56414d91bca360decdfa9288      M   52          20180605   72000.0
# 3  676506bad68e4161b9bbaffeb039626b      M   37          20170515   92000.0
# 4  8f7dd3b2afe14c078eb4f6e6fe4ba97d      M   48          20150903   62000.0
# 5  227f2d69e46a4899b70d48182822cff6      M   51          20180512  100000.0
# 6  bb0f25e23a4c4de6a645527c275cd594      M   56          20140611   76000.0
# 7  d72d201be5794279aa716d8ad82b8d90      F   51          20160223   73000.0
# 8  73ffefd41e9a4ca3ab26b2b3697c6eb7      F   67          20150929   67000.0
# 9  3e621194f72e40d7a0b695ee9b7c38b7      F   59          20170816   90000.0

# %%
profiles_of_interest.shape
# Out:
# (12202, 5)

# %%
profiles_of_interest['income'].hist()

# %%
transactions = transactions.rename(columns={'person':'id'})

# %%
transactions.set_index('id')
poi_transactions = pd.merge ( profiles_of_interest , transactions, on='id')

# %%
poi_transactions.loc[:,'amount'] = poi_transactions['value'].apply(lambda d: d['amount'])
poi_transactions.head(10)
# Out:
#                                  id gender  age  became_member_on   income  \
# 0  9fa9ae8f57894cc9a3b8a9bbe0fc1b2f      M   42          20160117  96000.0
# 1  9fa9ae8f57894cc9a3b8a9bbe0fc1b2f      M   42          20160117  96000.0
# 2  9fa9ae8f57894cc9a3b8a9bbe0fc1b2f      M   42          20160117  96000.0
# 3  9fa9ae8f57894cc9a3b8a9bbe0fc1b2f      M   42          20160117  96000.0
# 4  9fa9ae8f57894cc9a3b8a9bbe0fc1b2f      M   42          20160117  96000.0
# 5  9fa9ae8f57894cc9a3b8a9bbe0fc1b2f      M   42          20160117  96000.0
# 6  9fa9ae8f57894cc9a3b8a9bbe0fc1b2f      M   42          20160117  96000.0
# 7  9fa9ae8f57894cc9a3b8a9bbe0fc1b2f      M   42          20160117  96000.0
# 8  9fa9ae8f57894cc9a3b8a9bbe0fc1b2f      M   42          20160117  96000.0
# 9  9fa9ae8f57894cc9a3b8a9bbe0fc1b2f      M   42          20160117  96000.0
#
#          event              value  time  amount
# 0  transaction  {'amount': 21.55}    42   21.55
# 1  transaction  {'amount': 32.87}   114   32.87
# 2  transaction  {'amount': 19.99}   156   19.99
# 3  transaction  {'amount': 20.97}   168   20.97
# 4  transaction  {'amount': 31.09}   204   31.09
# 5  transaction  {'amount': 18.42}   354   18.42
# 6  transaction  {'amount': 29.71}   390   29.71
# 7  transaction  {'amount': 32.53}   396   32.53
# 8  transaction  {'amount': 33.36}   402   33.36
# 9  transaction  {'amount': 21.13}   474   21.13

# %%
relation_event_person = transcript.groupby(['person', 'event'])['time'].count()
relation_event_person.head(30)
# Out:
# person                            event
# 0009655768c64bdeb2e877511632db8f  offer completed     3
#                                   offer received      5
#                                   offer viewed        4
#                                   transaction         8
# 00116118485d4dfda04fdbaba9a87b5c  offer received      2
#                                   offer viewed        2
#                                   transaction         3
# 0011e0d4e6b944f998e987f904e8c1e5  offer completed     3
#                                   offer received      5
#                                   offer viewed        5
#                                   transaction         5
# 0020c2b971eb4e9188eac86d93036a77  offer completed     3
#                                   offer received      5
#                                   offer viewed        3
#                                   transaction         8
# 0020ccbbb6d84e358d3414a3ff76cffd  offer completed     3
#                                   offer received      4
#                                   offer viewed        4
#                                   transaction        12
# 003d66b6608740288d6cc97a6903f4f0  offer completed     3
#                                   offer received      5
#                                   offer viewed        4
#                                   transaction        18
# 00426fe3ffde4c6b9cb9ad6d077a13ea  offer completed     1
#                                   offer received      5
#                                   offer viewed        2
#                                   transaction        17
# 004b041fbfe44859945daa2c7f79ee64  offer completed     2
#                                   offer received      3
#                                   offer viewed        2
# Name: time, dtype: int64
